# %%
# %pip install pandas numpy matplotlib seaborn
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Collecting numpy
#   Downloading numpy-2.3.4-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 4.0 MB/s eta 0:00:00
# Collecting matplotlib
#   Downloading matplotlib-3.10.7-cp311-cp311-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/wuhaosheng/.pyenv/versions/3.11.8/envs/oci-env/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.60.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (112 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.9-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/wuhaosheng/.pyenv/versions/3.11.8/envs/oci-env/lib/python3.11/site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-12.0.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: six>=1.5 in /Users/wuhaosheng/.pyenv/versions/3.11.8/envs/oci-env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.3-cp311-cp311-macosx_11_0_arm64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 6.9 MB/s eta 0:00:0000:0100:01
# Downloading numpy-2.3.4-cp311-cp311-macosx_14_0_arm64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 11.0 MB/s eta 0:00:00a 0:00:01
# Downloading matplotlib-3.10.7-cp311-cp311-macosx_11_0_arm64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 11.8 MB/s eta 0:00:0000:0100:01
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached contourpy-1.3.3-cp311-cp311-macosx_11_0_arm64.whl (270 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.60.1-cp311-cp311-macosx_10_9_universal2.whl (2.8 MB)
# Using cached kiwisolver-1.4.9-cp311-cp311-macosx_11_0_arm64.whl (65 kB)
# Using cached pillow-12.0.0-cp311-cp311-macosx_11_0_arm64.whl (4.7 MB)
# Using cached pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, pandas, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.60.1 kiwisolver-1.4.9 matplotlib-3.10.7 numpy-2.3.4 pandas-2.3.3 pillow-12.0.0 pyparsing-3.2.5 pytz-2025.2 seaborn-0.13.2 tzdata-2025.2
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Raw Data Field Analysis Report
#
# ## 目標 (Objective)
#
# 深入分析台灣不動產交易原始資料，理解三種檔案格式的欄位結構、資料品質和業務含義。
#
# ## 分析檔案 (Analysis Files)
#
# - **a_lvr_land_a.csv** - 一般買賣交易資料 (Transaction Data)
# - **a_lvr_land_b.csv** - 預售屋交易資料 (Pre-sale Data)
# - **a_lvr_land_c.csv** - 租賃資料 (Rental Data)

# %%
# Import libraries
import pandas as pd
import numpy as np
from pathlib import Path

print("✅ Libraries imported")
# Out:
# ✅ Libraries imported

# %%
# Define file paths
DATA_DIR = Path("../data/raw")

files = {
    'transaction': DATA_DIR / "a_lvr_land_a.csv",
    'presale': DATA_DIR / "a_lvr_land_b.csv",
    'rental': DATA_DIR / "a_lvr_land_c.csv"
}

# Verify files exist
for name, path in files.items():
    if path.exists():
        size_kb = path.stat().st_size / 1024
        print(f"{name:12} | {size_kb:8.1f} KB")
    else:
        print(f"{name:12} | NOT FOUND")
# Out:
# transaction  |   1808.1 KB
# presale      |    303.3 KB
# rental       |   2475.0 KB

# %% [markdown]
# ## 2. Data Loading

# %%
# Load CSV files (skip English header row)
df_trans = pd.read_csv(files['transaction'], skiprows=[1])
df_presale = pd.read_csv(files['presale'], skiprows=[1])
df_rental = pd.read_csv(files['rental'], skiprows=[1])

print("Data loaded successfully")
print(f"Transaction: {df_trans.shape[0]:,} rows x {df_trans.shape[1]} columns")
print(f"Pre-sale:    {df_presale.shape[0]:,} rows x {df_presale.shape[1]} columns")
print(f"Rental:      {df_rental.shape[0]:,} rows x {df_rental.shape[1]} columns")
# Out:
# Data loaded successfully
# Transaction: 5,442 rows x 33 columns
# Pre-sale:    979 rows x 31 columns
# Rental:      5,802 rows x 35 columns

# %% [markdown]
# ## 3. Schema Comparison

# %%
# Display column names for each file
print("Column Names Comparison")
print("=" * 80)

print("\n[Transaction - 買賣交易]")
print(f"Total columns: {len(df_trans.columns)}")
for i, col in enumerate(df_trans.columns, 1):
    print(f"  {i:2}. {col}")

print("\n[Pre-sale - 預售屋]")
print(f"Total columns: {len(df_presale.columns)}")
for i, col in enumerate(df_presale.columns, 1):
    print(f"  {i:2}. {col}")

print("\n[Rental - 租賃]")
print(f"Total columns: {len(df_rental.columns)}")
for i, col in enumerate(df_rental.columns, 1):
    print(f"  {i:2}. {col}")
# Out:
# Column Names Comparison
# ================================================================================
#
# [Transaction - 買賣交易]
# Total columns: 33
#    1. 鄉鎮市區
#    2. 交易標的
#    3. 土地位置建物門牌
#    4. 土地移轉總面積平方公尺
#    5. 都市土地使用分區
#    6. 非都市土地使用分區
#    7. 非都市土地使用編定
#    8. 交易年月日
#    9. 交易筆棟數
#   10. 移轉層次
#   11. 總樓層數
#   12. 建物型態
#   13. 主要用途
#   14. 主要建材
#   15. 建築完成年月
#   16. 建物移轉總面積平方公尺
#   17. 建物現況格局-房
#   18. 建物現況格局-廳
#   19. 建物現況格局-衛
#   20. 建物現況格局-隔間
#   21. 有無管理組織
#   22. 總價元
#   23. 單價元平方公尺
#   24. 車位類別
#   25. 車位移轉總面積平方公尺
#   26. 車位總價元
#   27. 備註
#   28. 編號
#   29. 主建物面積
#   30. 附屬建物面積
#   31. 陽台面積
#   32. 電梯
#   33. 移轉編號
#
# [Pre-sale - 預售屋]
# Total columns: 31
#    1. 鄉鎮市區
#    2. 交易標的
#    3. 土地位置建物門牌
#    4. 土地移轉總面積平方公尺
#    5. 都市土地使用分區
#    6. 非都市土地使用分區
#    7. 非都市土地使用編定
#    8. 交易年月日
#    9. 交易筆棟數
#   10. 移轉層次
#   11. 總樓層數
#   12. 建物型態
#   13. 主要用途
#   14. 主要建材
#   15. 建築完成年月
#   16. 建物移轉總面積平方公尺
#   17. 建物現況格局-房
#   18. 建物現況格局-廳
#   19. 建物現況格局-衛
#   20. 建物現況格局-隔間
#   21. 有無管理組織
#   22. 總價元
#   23. 單價元平方公尺
#   24. 車位類別
#   25. 車位移轉總面積平方公尺
#   26. 車位總價元
#   27. 備註
#   28. 編號
#   29. 建案名稱
#   30. 棟及號
#   31. 解約情形
#
# [Rental - 租賃]
# Total columns: 35
#    1. 鄉鎮市區
#    2. 交易標的
#    3. 土地位置建物門牌
#    4. 土地面積平方公尺
#    5. 都市土地使用分區
#    6. 非都市土地使用分區
#    7. 非都市土地使用編定
#    8. 租賃年月日
#    9. 租賃筆棟數
#   10. 租賃層次
#   11. 總樓層數
#   12. 建物型態
#   13. 主要用途
#   14. 主要建材
#   15. 建築完成年月
#   16. 建物總面積平方公尺
#   17. 建物現況格局-房
#   18. 建物現況格局-廳
#   19. 建物現況格局-衛
#   20. 建物現況格局-隔間
#   21. 有無管理組織
#   22. 有無附傢俱
#   23. 總額元
#   24. 單價元平方公尺
#   25. 車位類別
#   26. 車位面積平方公尺
#   27. 車位總額元
#   28. 備註
#   29. 編號
#   30. 出租型態
#   31. 有無管理員
#   32. 租賃期間
#   33. 有無電梯
#   34. 附屬設備
#   35. 租賃住宅服務

# %%
# Find common and unique columns
cols_trans = set(df_trans.columns)
cols_presale = set(df_presale.columns)
cols_rental = set(df_rental.columns)

common_all = cols_trans & cols_presale & cols_rental
common_trans_presale = (cols_trans & cols_presale) - cols_rental
unique_trans = cols_trans - cols_presale - cols_rental
unique_presale = cols_presale - cols_trans - cols_rental
unique_rental = cols_rental - cols_trans - cols_presale

print("\n[Common Columns - All 3 Files]")
print(f"Count: {len(common_all)}")
for col in sorted(common_all):
    print(f"  - {col}")

print("\n[Common Columns - Transaction & Pre-sale Only]")
print(f"Count: {len(common_trans_presale)}")
for col in sorted(common_trans_presale):
    print(f"  - {col}")

print("\n[Unique to Transaction]")
print(f"Count: {len(unique_trans)}")
for col in sorted(unique_trans):
    print(f"  - {col}")

print("\n[Unique to Pre-sale]")
print(f"Count: {len(unique_presale)}")
for col in sorted(unique_presale):
    print(f"  - {col}")

print("\n[Unique to Rental]")
print(f"Count: {len(unique_rental)}")
for col in sorted(unique_rental):
    print(f"  - {col}")
# Out:
# [Common Columns - All 3 Files]
# Count: 20
#   - 主要建材
#   - 主要用途
#   - 交易標的
#   - 備註
#   - 單價元平方公尺
#   - 土地位置建物門牌
#   - 建物型態
#   - 建物現況格局-廳
#   - 建物現況格局-房
#   - 建物現況格局-衛
#   - 建物現況格局-隔間
#   - 建築完成年月
#   - 有無管理組織
#   - 編號
#   - 總樓層數
#   - 車位類別
#   - 都市土地使用分區
#   - 鄉鎮市區
#   - 非都市土地使用分區
#   - 非都市土地使用編定
#
# [Common Columns - Transaction & Pre-sale Only]
# Count: 8
#   - 交易年月日
#   - 交易筆棟數
#   - 土地移轉總面積平方公尺
#   - 建物移轉總面積平方公尺
#   - 移轉層次
#   - 總價元
#   - 車位移轉總面積平方公尺
#   - 車位總價元
#
# [Unique to Transaction]
# Count: 5
#   - 主建物面積
#   - 移轉編號
#   - 附屬建物面積
#   - 陽台面積
#   - 電梯
#
# [Unique to Pre-sale]
# Count: 3
#   - 建案名稱
#   - 棟及號
#   - 解約情形
#
# [Unique to Rental]
# Count: 15
#   - 出租型態
#   - 土地面積平方公尺
#   - 建物總面積平方公尺
#   - 有無管理員
#   - 有無附傢俱
#   - 有無電梯
#   - 租賃住宅服務
#   - 租賃層次
#   - 租賃年月日
#   - 租賃期間
#   - 租賃筆棟數
#   - 總額元
#   - 車位總額元
#   - 車位面積平方公尺
#   - 附屬設備

# %% [markdown]
# ## 4. Field-by-Field Analysis
#
# ### 4.1 Transaction Data (買賣交易)

# %%
# Helper function to analyze a single field
def analyze_field(df, col_name):
    """Analyze basic statistics for a field"""
    col = df[col_name]

    print(f"\n[{col_name}]")
    print(f"  Data Type:    {col.dtype}")
    print(f"  Non-null:     {col.notna().sum():,} ({col.notna().sum()/len(col)*100:.1f}%)")
    print(f"  Null:         {col.isna().sum():,} ({col.isna().sum()/len(col)*100:.1f}%)")
    print(f"  Unique:       {col.nunique():,}")

    # Numeric field analysis
    if pd.api.types.is_numeric_dtype(col):
        print(f"  Min:          {col.min()}")
        print(f"  Max:          {col.max()}")
        print(f"  Mean:         {col.mean():.2f}")
        print(f"  Median:       {col.median():.2f}")

    # Show top values for categorical/text fields
    if col.nunique() <= 50:
        print(f"  Top 10 Values:")
        for val, count in col.value_counts().head(10).items():
            print(f"    {val}: {count:,} ({count/len(col)*100:.1f}%)")

    # String length analysis for text fields
    if col.dtype == 'object':
        lengths = col.dropna().astype(str).str.len()
        if len(lengths) > 0:
            print(f"  String Length: min={lengths.min()}, max={lengths.max()}, avg={lengths.mean():.1f}")

print("Helper function defined")
# Out:
# Helper function defined

# %%
# Analyze all Transaction fields
print("=" * 80)
print("TRANSACTION DATA - FIELD ANALYSIS")
print("=" * 80)

for col in df_trans.columns:
    analyze_field(df_trans, col)
# Out:
# ================================================================================
# TRANSACTION DATA - FIELD ANALYSIS
# ================================================================================
#
# [鄉鎮市區]
#   Data Type:    object
#   Non-null:     5,442 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       12
#   Top 10 Values:
#     大安區: 685 (12.6%)
#     內湖區: 638 (11.7%)
#     中山區: 598 (11.0%)
#     北投區: 565 (10.4%)
#     文山區: 524 (9.6%)
#     士林區: 474 (8.7%)
#     信義區: 427 (7.8%)
#     松山區: 350 (6.4%)
#     大同區: 348 (6.4%)
#     萬華區: 333 (6.1%)
#   String Length: min=3, max=3, avg=3.0
#
# [交易標的]
#   Data Type:    object
#   Non-null:     5,442 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       5
#   Top 10 Values:
#     房地(土地+建物): 2,653 (48.8%)
#     房地(土地+建物)+車位: 1,524 (28.0%)
#     土地: 1,037 (19.1%)
#     車位: 200 (3.7%)
#     建物: 28 (0.5%)
#   String Length: min=2, max=12, avg=8.2
#
# [土地位置建物門牌]
#   Data Type:    object
#   Non-null:     5,442 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       5,043
#   String Length: min=8, max=172, avg=17.3
#
# [土地移轉總面積平方公尺]
#   Data Type:    float64
#   Non-null:     5,442 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       2,900
#   Min:          0.0
#   Max:          34050.26
#   Mean:         64.48
#   Median:       19.00
#
# [都市土地使用分區]
#   Data Type:    object
#   Non-null:     5,175 (95.1%)
#   Null:         267 (4.9%)
#   Unique:       163
#   String Length: min=1, max=101, avg=5.2
#
# [非都市土地使用分區]
#   Data Type:    float64
#   Non-null:     0 (0.0%)
#   Null:         5,442 (100.0%)
#   Unique:       0
#   Min:          nan
#   Max:          nan
#   Mean:         nan
#   Median:       nan
#   Top 10 Values:
#
# [非都市土地使用編定]
#   Data Type:    float64
#   Non-null:     0 (0.0%)
#   Null:         5,442 (100.0%)
#   Unique:       0
#   Min:          nan
#   Max:          nan
#   Mean:         nan
#   Median:       nan
#   Top 10 Values:
#
# [交易年月日]
#   Data Type:    int64
#   Non-null:     5,442 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       712
#   Min:          1040819
#   Max:          1140901
#   Mean:         1136037.09
#   Median:       1140526.00
#
# [交易筆棟數]
#   Data Type:    object
#   Non-null:     5,442 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       98
#   String Length: min=9, max=11, avg=9.0
#
# [移轉層次]
#   Data Type:    object
#   Non-null:     4,371 (80.3%)
#   Null:         1,071 (19.7%)
#   Unique:       116
#   String Length: min=1, max=27, avg=2.6
#
# [總樓層數]
#   Data Type:    object
#   Non-null:     4,367 (80.2%)
#   Null:         1,075 (19.8%)
#   Unique:       33
#   Top 10 Values:
#     五層: 623 (11.4%)
#     四層: 507 (9.3%)
#     七層: 450 (8.3%)
#     十二層: 401 (7.4%)
#     十四層: 311 (5.7%)
#     十五層: 271 (5.0%)
#     十層: 205 (3.8%)
#     十一層: 194 (3.6%)
#     十三層: 151 (2.8%)
#     八層: 134 (2.5%)
#   String Length: min=2, max=4, avg=2.6
#
# [建物型態]
#   Data Type:    object
#   Non-null:     5,442 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       5
#   Top 10 Values:
#     住宅大樓(11層含以上有電梯): 1,950 (35.8%)
#     其他: 1,237 (22.7%)
#     公寓(5樓含以下無電梯): 1,085 (19.9%)
#     華廈(10層含以下有電梯): 1,071 (19.7%)
#     透天厝: 99 (1.8%)
#   String Length: min=2, max=15, avg=10.8
#
# [主要用途]
#   Data Type:    object
#   Non-null:     4,269 (78.4%)
#   Null:         1,173 (21.6%)
#   Unique:       32
#   Top 10 Values:
#     住家用: 3,352 (61.6%)
#     商業用: 483 (8.9%)
#     辦公用: 117 (2.1%)
#     其他: 85 (1.6%)
#     工業用: 53 (1.0%)
#     停車空間: 45 (0.8%)
#     住商用: 30 (0.6%)
#     見使用執照: 29 (0.5%)
#     一般事務所: 17 (0.3%)
#     防空避難室兼停車場: 13 (0.2%)
#   String Length: min=2, max=16, avg=3.1
#
# [主要建材]
#   Data Type:    object
#   Non-null:     4,369 (80.3%)
#   Null:         1,073 (19.7%)
#   Unique:       20
#   Top 10 Values:
#     鋼筋混凝土造: 3,468 (63.7%)
#     鋼骨鋼筋混凝土造: 366 (6.7%)
#     鋼骨造: 221 (4.1%)
#     加強磚造: 215 (4.0%)
#     ＲＣ造: 50 (0.9%)
#     磚造: 19 (0.3%)
#     見使用執照: 9 (0.2%)
#     木造: 3 (0.1%)
#     鋼構造: 3 (0.1%)
#     鋼骨混凝土造: 3 (0.1%)
#   String Length: min=2, max=19, avg=5.9
#
# [建築完成年月]
#   Data Type:    float64
#   Non-null:     4,275 (78.6%)
#   Null:         1,167 (21.4%)
#   Unique:       2,480
#   Min:          4501.0
#   Max:          1140701.0
#   Mean:         865778.09
#   Median:       840414.00
#
# [建物移轉總面積平方公尺]
#   Data Type:    float64
#   Non-null:     5,442 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       3,575
#   Min:          0.0
#   Max:          12596.02
#   Mean:         113.85
#   Median:       86.25
#
# [建物現況格局-房]
#   Data Type:    int64
#   Non-null:     5,442 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       15
#   Min:          0
#   Max:          32
#   Mean:         1.86
#   Median:       2.00
#   Top 10 Values:
#     0: 1,698 (31.2%)
#     3: 1,528 (28.1%)
#     2: 877 (16.1%)
#     1: 635 (11.7%)
#     4: 550 (10.1%)
#     5: 96 (1.8%)
#     6: 24 (0.4%)
#     8: 10 (0.2%)
#     7: 10 (0.2%)
#     9: 5 (0.1%)
#
# [建物現況格局-廳]
#   Data Type:    int64
#   Non-null:     5,442 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       9
#   Min:          0
#   Max:          12
#   Mean:         1.19
#   Median:       1.00
#   Top 10 Values:
#     2: 2,543 (46.7%)
#     0: 1,730 (31.8%)
#     1: 1,075 (19.8%)
#     3: 67 (1.2%)
#     4: 20 (0.4%)
#     5: 4 (0.1%)
#     12: 1 (0.0%)
#     9: 1 (0.0%)
#     7: 1 (0.0%)
#
# [建物現況格局-衛]
#   Data Type:    int64
#   Non-null:     5,442 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       12
#   Min:          0
#   Max:          14
#   Mean:         1.18
#   Median:       1.00
#   Top 10 Values:
#     2: 1,824 (33.5%)
#     1: 1,723 (31.7%)
#     0: 1,596 (29.3%)
#     3: 204 (3.7%)
#     4: 57 (1.0%)
#     5: 23 (0.4%)
#     6: 5 (0.1%)
#     7: 4 (0.1%)
#     8: 2 (0.0%)
#     9: 2 (0.0%)
#
# [建物現況格局-隔間]
#   Data Type:    object
#   Non-null:     5,442 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       2
#   Top 10 Values:
#     有: 3,889 (71.5%)
#     無: 1,553 (28.5%)
#   String Length: min=1, max=1, avg=1.0
#
# [有無管理組織]
#   Data Type:    object
#   Non-null:     5,442 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       2
#   Top 10 Values:
#     有: 2,967 (54.5%)
#     無: 2,475 (45.5%)
#   String Length: min=1, max=1, avg=1.0
#
# [總價元]
#   Data Type:    int64
#   Non-null:     5,442 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       2,599
#   Min:          315
#   Max:          3082217091
#   Mean:         28596036.98
#   Median:       18300000.00
#
# [單價元平方公尺]
#   Data Type:    float64
#   Non-null:     5,242 (96.3%)
#   Null:         200 (3.7%)
#   Unique:       4,820
#   Min:          0.0
#   Max:          3585871.0
#   Mean:         232395.46
#   Median:       215765.50
#
# [車位類別]
#   Data Type:    object
#   Non-null:     1,726 (31.7%)
#   Null:         3,716 (68.3%)
#   Unique:       7
#   Top 10 Values:
#     坡道平面: 1,307 (24.0%)
#     坡道機械: 120 (2.2%)
#     塔式車位: 90 (1.7%)
#     升降機械: 89 (1.6%)
#     其他: 57 (1.0%)
#     升降平面: 54 (1.0%)
#     一樓平面: 9 (0.2%)
#   String Length: min=2, max=4, avg=3.9
#
# [車位移轉總面積平方公尺]
#   Data Type:    float64
#   Non-null:     5,442 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       745
#   Min:          0.0
#   Max:          2134.64
#   Mean:         12.02
#   Median:       0.00
#
# [車位總價元]
#   Data Type:    int64
#   Non-null:     5,442 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       212
#   Min:          0
#   Max:          129200000
#   Mean:         968378.02
#   Median:       0.00
#
# [備註]
#   Data Type:    object
#   Non-null:     4,230 (77.7%)
#   Null:         1,212 (22.3%)
#   Unique:       622
#   String Length: min=3, max=155, avg=18.9
#
# [編號]
#   Data Type:    object
#   Non-null:     5,442 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       5,442
#   String Length: min=19, max=19, avg=19.0
#
# [主建物面積]
#   Data Type:    float64
#   Non-null:     5,442 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       3,108
#   Min:          0.0
#   Max:          5218.27
#   Mean:         67.96
#   Median:       57.85
#
# [附屬建物面積]
#   Data Type:    float64
#   Non-null:     5,442 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       800
#   Min:          0.0
#   Max:          246.74
#   Mean:         2.30
#   Median:       0.00
#
# [陽台面積]
#   Data Type:    float64
#   Non-null:     5,442 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       1,390
#   Min:          0.0
#   Max:          450.15
#   Mean:         5.81
#   Median:       3.71
#
# [電梯]
#   Data Type:    object
#   Non-null:     5,442 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       2
#   Top 10 Values:
#     有: 3,206 (58.9%)
#     無: 2,236 (41.1%)
#   String Length: min=1, max=1, avg=1.0
#
# [移轉編號]
#   Data Type:    float64
#   Non-null:     1,973 (36.3%)
#   Null:         3,469 (63.7%)
#   Unique:       1,600
#   Min:          1.0
#   Max:          1971.0
#   Mean:         943.38
#   Median:       962.00
# /Users/wuhaosheng/.pyenv/versions/3.11.8/envs/oci-env/lib/python3.11/site-packages/numpy/lib/_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /Users/wuhaosheng/.pyenv/versions/3.11.8/envs/oci-env/lib/python3.11/site-packages/numpy/lib/_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %% [markdown]
# ### 4.2 Pre-sale Data (預售屋)

# %%
# Analyze all Pre-sale fields
print("=" * 80)
print("PRE-SALE DATA - FIELD ANALYSIS")
print("=" * 80)

for col in df_presale.columns:
    analyze_field(df_presale, col)
# Out:
# ================================================================================
# PRE-SALE DATA - FIELD ANALYSIS
# ================================================================================
#
# [鄉鎮市區]
#   Data Type:    object
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       12
#   Top 10 Values:
#     北投區: 358 (36.6%)
#     大同區: 138 (14.1%)
#     文山區: 118 (12.1%)
#     南港區: 87 (8.9%)
#     大安區: 56 (5.7%)
#     士林區: 47 (4.8%)
#     中山區: 42 (4.3%)
#     萬華區: 40 (4.1%)
#     中正區: 31 (3.2%)
#     內湖區: 31 (3.2%)
#   String Length: min=3, max=3, avg=3.0
#
# [交易標的]
#   Data Type:    object
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       3
#   Top 10 Values:
#     房地(土地+建物)+車位: 731 (74.7%)
#     房地(土地+建物): 243 (24.8%)
#     車位: 5 (0.5%)
#   String Length: min=2, max=12, avg=11.2
#
# [土地位置建物門牌]
#   Data Type:    object
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       127
#   String Length: min=9, max=28, avg=14.3
#
# [土地移轉總面積平方公尺]
#   Data Type:    float64
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       399
#   Min:          0.0
#   Max:          198.22
#   Mean:         18.75
#   Median:       16.10
#
# [都市土地使用分區]
#   Data Type:    object
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       4
#   Top 10 Values:
#     住: 579 (59.1%)
#     商: 226 (23.1%)
#     其他: 165 (16.9%)
#     工: 9 (0.9%)
#   String Length: min=1, max=2, avg=1.2
#
# [非都市土地使用分區]
#   Data Type:    object
#   Non-null:     5 (0.5%)
#   Null:         974 (99.5%)
#   Unique:       1
#   Top 10 Values:
#     特定專用區: 5 (0.5%)
#   String Length: min=5, max=5, avg=5.0
#
# [非都市土地使用編定]
#   Data Type:    float64
#   Non-null:     0 (0.0%)
#   Null:         979 (100.0%)
#   Unique:       0
#   Min:          nan
#   Max:          nan
#   Mean:         nan
#   Median:       nan
#   Top 10 Values:
#
# [交易年月日]
#   Data Type:    int64
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       91
#   Min:          1140511
#   Max:          1140810
#   Mean:         1140627.67
#   Median:       1140613.00
#
# [交易筆棟數]
#   Data Type:    object
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       68
#   String Length: min=9, max=10, avg=9.2
#
# [移轉層次]
#   Data Type:    object
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       39
#   Top 10 Values:
#     三層: 76 (7.8%)
#     六層: 72 (7.4%)
#     五層: 71 (7.3%)
#     四層: 63 (6.4%)
#     九層: 62 (6.3%)
#     八層: 57 (5.8%)
#     七層: 57 (5.8%)
#     二層: 56 (5.7%)
#     十三層: 55 (5.6%)
#     十一層: 49 (5.0%)
#   String Length: min=1, max=4, avg=2.5
#
# [總樓層數]
#   Data Type:    int64
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       29
#   Min:          0
#   Max:          36
#   Mean:         18.53
#   Median:       15.00
#   Top 10 Values:
#     24: 112 (11.4%)
#     15: 105 (10.7%)
#     14: 102 (10.4%)
#     11: 88 (9.0%)
#     12: 65 (6.6%)
#     26: 55 (5.6%)
#     10: 53 (5.4%)
#     22: 51 (5.2%)
#     21: 51 (5.2%)
#     33: 38 (3.9%)
#
# [建物型態]
#   Data Type:    object
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       7
#   Top 10 Values:
#     住宅大樓(11層含以上有電梯): 864 (88.3%)
#     華廈(10層含以下有電梯): 93 (9.5%)
#     廠辦: 9 (0.9%)
#     店面(店鋪): 4 (0.4%)
#     透天厝: 4 (0.4%)
#     辦公商業大樓: 3 (0.3%)
#     其他: 2 (0.2%)
#   String Length: min=2, max=15, avg=14.6
#
# [主要用途]
#   Data Type:    object
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       6
#   Top 10 Values:
#     住家用: 864 (88.3%)
#     見其他登記事項: 50 (5.1%)
#     住商用: 45 (4.6%)
#     商業用: 13 (1.3%)
#     停車空間: 4 (0.4%)
#     工業用: 3 (0.3%)
#   String Length: min=3, max=7, avg=3.2
#
# [主要建材]
#   Data Type:    object
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       5
#   Top 10 Values:
#     鋼筋混凝土造: 600 (61.3%)
#     鋼骨鋼筋混凝土造: 252 (25.7%)
#     見其他登記事項: 117 (12.0%)
#     鋼骨混凝土造: 9 (0.9%)
#     混凝土造: 1 (0.1%)
#   String Length: min=4, max=8, avg=6.6
#
# [建築完成年月]
#   Data Type:    float64
#   Non-null:     0 (0.0%)
#   Null:         979 (100.0%)
#   Unique:       0
#   Min:          nan
#   Max:          nan
#   Mean:         nan
#   Median:       nan
#   Top 10 Values:
#
# [建物移轉總面積平方公尺]
#   Data Type:    float64
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       530
#   Min:          0.0
#   Max:          1115.45
#   Mean:         138.41
#   Median:       130.42
#
# [建物現況格局-房]
#   Data Type:    int64
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       5
#   Min:          0
#   Max:          4
#   Mean:         2.21
#   Median:       2.00
#   Top 10 Values:
#     3: 408 (41.7%)
#     2: 369 (37.7%)
#     0: 92 (9.4%)
#     1: 80 (8.2%)
#     4: 30 (3.1%)
#
# [建物現況格局-廳]
#   Data Type:    int64
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       3
#   Min:          0
#   Max:          2
#   Mean:         1.63
#   Median:       2.00
#   Top 10 Values:
#     2: 713 (72.8%)
#     1: 171 (17.5%)
#     0: 95 (9.7%)
#
# [建物現況格局-衛]
#   Data Type:    int64
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       4
#   Min:          0
#   Max:          3
#   Mean:         1.67
#   Median:       2.00
#   Top 10 Values:
#     2: 623 (63.6%)
#     1: 254 (25.9%)
#     0: 56 (5.7%)
#     3: 46 (4.7%)
#
# [建物現況格局-隔間]
#   Data Type:    object
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       2
#   Top 10 Values:
#     有: 928 (94.8%)
#     無: 51 (5.2%)
#   String Length: min=1, max=1, avg=1.0
#
# [有無管理組織]
#   Data Type:    object
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       1
#   Top 10 Values:
#     無: 979 (100.0%)
#   String Length: min=1, max=1, avg=1.0
#
# [總價元]
#   Data Type:    int64
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       820
#   Min:          2000000
#   Max:          307480000
#   Mean:         43507624.51
#   Median:       39160000.00
#
# [單價元平方公尺]
#   Data Type:    float64
#   Non-null:     974 (99.5%)
#   Null:         5 (0.5%)
#   Unique:       935
#   Min:          66166.0
#   Max:          679787.0
#   Mean:         365628.49
#   Median:       355116.50
#
# [車位類別]
#   Data Type:    object
#   Non-null:     732 (74.8%)
#   Null:         247 (25.2%)
#   Unique:       7
#   Top 10 Values:
#     坡道平面: 635 (64.9%)
#     升降機械: 29 (3.0%)
#     其他: 26 (2.7%)
#     坡道機械: 23 (2.3%)
#     升降平面: 15 (1.5%)
#     塔式車位: 3 (0.3%)
#     一樓平面: 1 (0.1%)
#   String Length: min=2, max=4, avg=3.9
#
# [車位移轉總面積平方公尺]
#   Data Type:    float64
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       148
#   Min:          0.0
#   Max:          451.44
#   Mean:         26.51
#   Median:       29.00
#
# [車位總價元]
#   Data Type:    int64
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       95
#   Min:          0
#   Max:          28270000
#   Mean:         2613536.26
#   Median:       3000000.00
#
# [備註]
#   Data Type:    object
#   Non-null:     194 (19.8%)
#   Null:         785 (80.2%)
#   Unique:       69
#   String Length: min=2, max=71, avg=18.0
#
# [編號]
#   Data Type:    object
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       979
#   String Length: min=19, max=19, avg=19.0
#
# [建案名稱]
#   Data Type:    object
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       122
#   String Length: min=2, max=12, avg=4.7
#
# [棟及號]
#   Data Type:    object
#   Non-null:     979 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       731
#   String Length: min=2, max=10, avg=6.5
#
# [解約情形]
#   Data Type:    object
#   Non-null:     3 (0.3%)
#   Null:         976 (99.7%)
#   Unique:       2
#   Top 10 Values:
#     1140826全部解約: 2 (0.2%)
#     1140629全部解約: 1 (0.1%)
#   String Length: min=11, max=11, avg=11.0
# /Users/wuhaosheng/.pyenv/versions/3.11.8/envs/oci-env/lib/python3.11/site-packages/numpy/lib/_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /Users/wuhaosheng/.pyenv/versions/3.11.8/envs/oci-env/lib/python3.11/site-packages/numpy/lib/_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %% [markdown]
# ### 4.3 Rental Data (租賃)

# %%
# Analyze all Rental fields
print("=" * 80)
print("RENTAL DATA - FIELD ANALYSIS")
print("=" * 80)

for col in df_rental.columns:
    analyze_field(df_rental, col)
# Out:
# ================================================================================
# RENTAL DATA - FIELD ANALYSIS
# ================================================================================
#
# [鄉鎮市區]
#   Data Type:    object
#   Non-null:     5,802 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       12
#   Top 10 Values:
#     中山區: 981 (16.9%)
#     大安區: 561 (9.7%)
#     萬華區: 533 (9.2%)
#     士林區: 489 (8.4%)
#     大同區: 484 (8.3%)
#     中正區: 459 (7.9%)
#     信義區: 449 (7.7%)
#     內湖區: 448 (7.7%)
#     文山區: 431 (7.4%)
#     松山區: 420 (7.2%)
#   String Length: min=3, max=3, avg=3.0
#
# [交易標的]
#   Data Type:    object
#   Non-null:     5,802 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       4
#   Top 10 Values:
#     租賃房屋: 5,526 (95.2%)
#     租賃房屋+車位: 251 (4.3%)
#     車位: 23 (0.4%)
#     土地: 2 (0.0%)
#   String Length: min=2, max=7, avg=4.1
#
# [土地位置建物門牌]
#   Data Type:    object
#   Non-null:     5,802 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       4,878
#   String Length: min=9, max=43, avg=18.1
#
# [土地面積平方公尺]
#   Data Type:    float64
#   Non-null:     5,802 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       99
#   Min:          0.0
#   Max:          1891.61
#   Mean:         1.20
#   Median:       0.00
#
# [都市土地使用分區]
#   Data Type:    object
#   Non-null:     132 (2.3%)
#   Null:         5,670 (97.7%)
#   Unique:       4
#   Top 10 Values:
#     住: 68 (1.2%)
#     商: 47 (0.8%)
#     其他: 10 (0.2%)
#     工: 7 (0.1%)
#   String Length: min=1, max=2, avg=1.1
#
# [非都市土地使用分區]
#   Data Type:    float64
#   Non-null:     0 (0.0%)
#   Null:         5,802 (100.0%)
#   Unique:       0
#   Min:          nan
#   Max:          nan
#   Mean:         nan
#   Median:       nan
#   Top 10 Values:
#
# [非都市土地使用編定]
#   Data Type:    float64
#   Non-null:     0 (0.0%)
#   Null:         5,802 (100.0%)
#   Unique:       0
#   Min:          nan
#   Max:          nan
#   Mean:         nan
#   Median:       nan
#   Top 10 Values:
#
# [租賃年月日]
#   Data Type:    int64
#   Non-null:     5,802 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       92
#   Min:          1140511
#   Max:          1140810
#   Mean:         1140647.51
#   Median:       1140625.00
#
# [租賃筆棟數]
#   Data Type:    object
#   Non-null:     5,802 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       36
#   Top 10 Values:
#     土地0建物1車位0: 3,794 (65.4%)
#     土地0建物0車位0: 1,590 (27.4%)
#     土地0建物1車位1: 176 (3.0%)
#     土地1建物1車位0: 83 (1.4%)
#     土地0建物1車位2: 41 (0.7%)
#     土地0建物0車位1: 25 (0.4%)
#     土地0建物2車位0: 20 (0.3%)
#     土地2建物1車位0: 11 (0.2%)
#     土地1建物1車位1: 8 (0.1%)
#     土地3建物1車位0: 6 (0.1%)
#   String Length: min=9, max=11, avg=9.0
#
# [租賃層次]
#   Data Type:    object
#   Non-null:     5,778 (99.6%)
#   Null:         24 (0.4%)
#   Unique:       29
#   Top 10 Values:
#     四層: 953 (16.4%)
#     三層: 886 (15.3%)
#     二層: 833 (14.4%)
#     五層: 635 (10.9%)
#     一層: 484 (8.3%)
#     全: 377 (6.5%)
#     六層: 272 (4.7%)
#     七層: 257 (4.4%)
#     八層: 231 (4.0%)
#     九層: 181 (3.1%)
#   String Length: min=1, max=7, avg=2.1
#
# [總樓層數]
#   Data Type:    float64
#   Non-null:     5,786 (99.7%)
#   Null:         16 (0.3%)
#   Unique:       36
#   Min:          0.0
#   Max:          46.0
#   Mean:         8.01
#   Median:       6.00
#   Top 10 Values:
#     4.0: 1,348 (23.2%)
#     5.0: 1,176 (20.3%)
#     12.0: 556 (9.6%)
#     7.0: 496 (8.5%)
#     14.0: 345 (5.9%)
#     15.0: 241 (4.2%)
#     11.0: 205 (3.5%)
#     6.0: 201 (3.5%)
#     10.0: 192 (3.3%)
#     3.0: 163 (2.8%)
#
# [建物型態]
#   Data Type:    object
#   Non-null:     5,802 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       8
#   Top 10 Values:
#     公寓(5樓含以下無電梯): 2,255 (38.9%)
#     住宅大樓(11層含以上有電梯): 1,528 (26.3%)
#     華廈(10層含以下有電梯): 1,181 (20.4%)
#     透天厝: 377 (6.5%)
#     辦公商業大樓: 216 (3.7%)
#     店面(店鋪): 188 (3.2%)
#     其他: 34 (0.6%)
#     廠辦: 23 (0.4%)
#   String Length: min=2, max=15, avg=11.9
#
# [主要用途]
#   Data Type:    object
#   Non-null:     5,343 (92.1%)
#   Null:         459 (7.9%)
#   Unique:       101
#   String Length: min=2, max=60, avg=3.5
#
# [主要建材]
#   Data Type:    object
#   Non-null:     5,782 (99.7%)
#   Null:         20 (0.3%)
#   Unique:       19
#   Top 10 Values:
#     鋼筋混凝土造: 4,842 (83.5%)
#     加強磚造: 624 (10.8%)
#     鋼骨鋼筋混凝土造: 129 (2.2%)
#     鋼骨造: 106 (1.8%)
#     見使用執照: 23 (0.4%)
#     磚造: 22 (0.4%)
#     鋼骨混凝土造: 19 (0.3%)
#     木石磚造（磚石造）: 2 (0.0%)
#     預力混凝土造: 2 (0.0%)
#     壹、貳層鋼筋混凝土造，參層磚牆石棉瓦屋頂: 2 (0.0%)
#   String Length: min=2, max=20, avg=5.8
#
# [建築完成年月]
#   Data Type:    float64
#   Non-null:     5,456 (94.0%)
#   Null:         346 (6.0%)
#   Unique:       2,719
#   Min:          460824.0
#   Max:          1140107.0
#   Mean:         759547.52
#   Median:       711227.00
#
# [建物總面積平方公尺]
#   Data Type:    float64
#   Non-null:     5,802 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       3,895
#   Min:          0.0
#   Max:          7230.299999999999
#   Mean:         77.23
#   Median:       51.70
#
# [建物現況格局-房]
#   Data Type:    int64
#   Non-null:     5,802 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       33
#   Min:          0
#   Max:          3122
#   Mean:         7.85
#   Median:       3.00
#   Top 10 Values:
#     1: 1,425 (24.6%)
#     3: 1,271 (21.9%)
#     2: 963 (16.6%)
#     4: 627 (10.8%)
#     0: 472 (8.1%)
#     5: 406 (7.0%)
#     6: 131 (2.3%)
#     300: 73 (1.3%)
#     8: 59 (1.0%)
#     7: 49 (0.8%)
#
# [建物現況格局-廳]
#   Data Type:    int64
#   Non-null:     5,802 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       12
#   Min:          0
#   Max:          35
#   Mean:         1.28
#   Median:       1.00
#   Top 10 Values:
#     1: 2,314 (39.9%)
#     2: 1,687 (29.1%)
#     0: 1,609 (27.7%)
#     10: 75 (1.3%)
#     3: 38 (0.7%)
#     5: 23 (0.4%)
#     4: 22 (0.4%)
#     35: 15 (0.3%)
#     7: 10 (0.2%)
#     6: 6 (0.1%)
#
# [建物現況格局-衛]
#   Data Type:    int64
#   Non-null:     5,802 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       27
#   Min:          0
#   Max:          300
#   Mean:         6.20
#   Median:       1.00
#   Top 10 Values:
#     1: 2,836 (48.9%)
#     2: 1,435 (24.7%)
#     0: 431 (7.4%)
#     3: 274 (4.7%)
#     4: 198 (3.4%)
#     5: 122 (2.1%)
#     300: 73 (1.3%)
#     6: 66 (1.1%)
#     8: 57 (1.0%)
#     7: 46 (0.8%)
#
# [建物現況格局-隔間]
#   Data Type:    object
#   Non-null:     5,802 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       2
#   Top 10 Values:
#     有: 5,428 (93.6%)
#     無: 374 (6.4%)
#   String Length: min=1, max=1, avg=1.0
#
# [有無管理組織]
#   Data Type:    object
#   Non-null:     5,802 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       2
#   Top 10 Values:
#     無: 3,086 (53.2%)
#     有: 2,716 (46.8%)
#   String Length: min=1, max=1, avg=1.0
#
# [有無附傢俱]
#   Data Type:    object
#   Non-null:     5,802 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       2
#   Top 10 Values:
#     有: 4,152 (71.6%)
#     無: 1,650 (28.4%)
#   String Length: min=1, max=1, avg=1.0
#
# [總額元]
#   Data Type:    int64
#   Non-null:     5,802 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       759
#   Min:          2600
#   Max:          2033340
#   Mean:         36012.46
#   Median:       22000.00
#
# [單價元平方公尺]
#   Data Type:    float64
#   Non-null:     5,779 (99.6%)
#   Null:         23 (0.4%)
#   Unique:       1,086
#   Min:          71.0
#   Max:          4288.0
#   Mean:         539.53
#   Median:       472.00
#
# [車位類別]
#   Data Type:    object
#   Non-null:     274 (4.7%)
#   Null:         5,528 (95.3%)
#   Unique:       7
#   Top 10 Values:
#     坡道平面: 219 (3.8%)
#     升降機械: 16 (0.3%)
#     坡道機械: 13 (0.2%)
#     升降平面: 12 (0.2%)
#     一樓平面: 7 (0.1%)
#     其他: 4 (0.1%)
#     塔式車位: 3 (0.1%)
#   String Length: min=2, max=4, avg=4.0
#
# [車位面積平方公尺]
#   Data Type:    float64
#   Non-null:     5,802 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       160
#   Min:          0.0
#   Max:          2156.73
#   Mean:         1.66
#   Median:       0.00
#
# [車位總額元]
#   Data Type:    int64
#   Non-null:     5,802 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       29
#   Min:          0
#   Max:          72500
#   Mean:         64.33
#   Median:       0.00
#   Top 10 Values:
#     0: 5,757 (99.2%)
#     4000: 7 (0.1%)
#     3000: 5 (0.1%)
#     7392: 3 (0.1%)
#     4200: 2 (0.0%)
#     3500: 2 (0.0%)
#     2600: 2 (0.0%)
#     6000: 2 (0.0%)
#     3900: 2 (0.0%)
#     19000: 1 (0.0%)
#
# [備註]
#   Data Type:    object
#   Non-null:     4,397 (75.8%)
#   Null:         1,405 (24.2%)
#   Unique:       1,832
#   String Length: min=2, max=477, avg=40.4
#
# [編號]
#   Data Type:    object
#   Non-null:     5,802 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       5,802
#   String Length: min=19, max=19, avg=19.0
#
# [出租型態]
#   Data Type:    object
#   Non-null:     5,138 (88.6%)
#   Null:         664 (11.4%)
#   Unique:       5
#   Top 10 Values:
#     整棟(戶)出租: 2,374 (40.9%)
#     獨立套房: 1,117 (19.3%)
#     分租套房: 1,109 (19.1%)
#     分租雅房: 503 (8.7%)
#     分層出租: 35 (0.6%)
#   String Length: min=4, max=7, avg=5.4
#
# [有無管理員]
#   Data Type:    object
#   Non-null:     5,777 (99.6%)
#   Null:         25 (0.4%)
#   Unique:       2
#   Top 10 Values:
#     無: 3,228 (55.6%)
#     有: 2,549 (43.9%)
#   String Length: min=1, max=1, avg=1.0
#
# [租賃期間]
#   Data Type:    object
#   Non-null:     5,802 (100.0%)
#   Null:         0 (0.0%)
#   Unique:       1,256
#   String Length: min=15, max=15, avg=15.0
#
# [有無電梯]
#   Data Type:    object
#   Non-null:     5,777 (99.6%)
#   Null:         25 (0.4%)
#   Unique:       2
#   Top 10 Values:
#     有: 3,075 (53.0%)
#     無: 2,702 (46.6%)
#   String Length: min=1, max=1, avg=1.0
#
# [附屬設備]
#   Data Type:    object
#   Non-null:     5,152 (88.8%)
#   Null:         650 (11.2%)
#   Unique:       107
#   String Length: min=2, max=32, avg=16.6
#
# [租賃住宅服務]
#   Data Type:    object
#   Non-null:     4,042 (69.7%)
#   Null:         1,760 (30.3%)
#   Unique:       5
#   Top 10 Values:
#     一般轉租: 1,519 (26.2%)
#     社會住宅代管: 1,193 (20.6%)
#     社會住宅包租轉租: 1,109 (19.1%)
#     一般代管: 159 (2.7%)
#     一般包租: 62 (1.1%)
#   String Length: min=4, max=8, avg=5.7
# /Users/wuhaosheng/.pyenv/versions/3.11.8/envs/oci-env/lib/python3.11/site-packages/numpy/lib/_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /Users/wuhaosheng/.pyenv/versions/3.11.8/envs/oci-env/lib/python3.11/site-packages/numpy/lib/_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %% [markdown]
# ## 5. Data Quality Assessment
#
# ### 5.1 Completeness - Missing Values

# %%
# Calculate missing values for each dataset
def missing_value_report(df, dataset_name):
    """Generate missing value report"""
    missing = df.isnull().sum()
    missing_pct = (missing / len(df)) * 100

    report = pd.DataFrame({
        'Column': df.columns,
        'Missing_Count': missing.values,
        'Missing_Percent': missing_pct.values
    })

    report = report[report['Missing_Count'] > 0].sort_values('Missing_Count', ascending=False)

    print(f"\n[{dataset_name}]")
    print(f"Total rows: {len(df):,}")
    print(f"Columns with missing values: {len(report)}/{len(df.columns)}")

    if len(report) > 0:
        print("\nTop missing fields:")
        for _, row in report.head(20).iterrows():
            print(f"  {row['Column']:30} | {row['Missing_Count']:>8,.0f} ({row['Missing_Percent']:>5.1f}%)")
    else:
        print("No missing values found")

    return report

# Generate reports
missing_trans = missing_value_report(df_trans, "Transaction")
missing_presale = missing_value_report(df_presale, "Pre-sale")
missing_rental = missing_value_report(df_rental, "Rental")
# Out:
# [Transaction]
# Total rows: 5,442
# Columns with missing values: 12/33
#
# Top missing fields:
#   非都市土地使用分區                      |    5,442 (100.0%)
#   非都市土地使用編定                      |    5,442 (100.0%)
#   車位類別                           |    3,716 ( 68.3%)
#   移轉編號                           |    3,469 ( 63.7%)
#   備註                             |    1,212 ( 22.3%)
#   主要用途                           |    1,173 ( 21.6%)
#   建築完成年月                         |    1,167 ( 21.4%)
#   總樓層數                           |    1,075 ( 19.8%)
#   主要建材                           |    1,073 ( 19.7%)
#   移轉層次                           |    1,071 ( 19.7%)
#   都市土地使用分區                       |      267 (  4.9%)
#   單價元平方公尺                        |      200 (  3.7%)
#
# [Pre-sale]
# Total rows: 979
# Columns with missing values: 7/31
#
# Top missing fields:
#   非都市土地使用編定                      |      979 (100.0%)
#   建築完成年月                         |      979 (100.0%)
#   解約情形                           |      976 ( 99.7%)
#   非都市土地使用分區                      |      974 ( 99.5%)
#   備註                             |      785 ( 80.2%)
#   車位類別                           |      247 ( 25.2%)
#   單價元平方公尺                        |        5 (  0.5%)
#
# [Rental]
# Total rows: 5,802
# Columns with missing values: 16/35
#
# Top missing fields:
#   非都市土地使用分區                      |    5,802 (100.0%)
#   非都市土地使用編定                      |    5,802 (100.0%)
#   都市土地使用分區                       |    5,670 ( 97.7%)
#   車位類別                           |    5,528 ( 95.3%)
#   租賃住宅服務                         |    1,760 ( 30.3%)
#   備註                             |    1,405 ( 24.2%)
#   出租型態                           |      664 ( 11.4%)
#   附屬設備                           |      650 ( 11.2%)
#   主要用途                           |      459 (  7.9%)
#   建築完成年月                         |      346 (  6.0%)
#   有無管理員                          |       25 (  0.4%)
#   有無電梯                           |       25 (  0.4%)
#   租賃層次                           |       24 (  0.4%)
#   單價元平方公尺                        |       23 (  0.4%)
#   主要建材                           |       20 (  0.3%)
#   總樓層數                           |       16 (  0.3%)

# %% [markdown]
# ## 6. Summary & Recommendations

# %%
# Generate comprehensive recommendations
print("=" * 80)
print("ANALYSIS SUMMARY & RECOMMENDATIONS")
print("=" * 80)

print("\n[1. FILE FORMAT UNDERSTANDING]")
print("  - Transaction (a): General property sales - 32 fields")
print("  - Pre-sale (b): Pre-construction sales - 30 fields")
print("  - Rental (c): Property rentals - 34 fields")

print("\n[2. COMMON FIELDS]")
common = sorted(cols_trans & cols_presale & cols_rental)
print(f"  - {len(common)} fields shared across all 3 formats")
print(f"  - Core fields: 鄉鎮市區, 交易標的, 土地位置建物門牌, 交易年月日, etc.")

print("\n[3. FORMAT-SPECIFIC FIELDS]")
if len(unique_trans) > 0:
    print(f"  Transaction-only: {', '.join(sorted(unique_trans))}")
if len(unique_presale) > 0:
    print(f"  Pre-sale-only: {', '.join(sorted(unique_presale))}")
if len(unique_rental) > 0:
    print(f"  Rental-only (first 5): {', '.join(sorted(list(unique_rental)[:5]))}")

print("\n[4. DATA QUALITY INSIGHTS]")
print(f"  Transaction: {len(missing_trans)} fields with missing values")
print(f"  Pre-sale:    {len(missing_presale)} fields with missing values")
print(f"  Rental:      {len(missing_rental)} fields with missing values")

print("\n[5. RECOMMENDATIONS FOR ETL]")
print("  a) Field Mapping:")
print("     - Standardize common field names across 3 formats")
print("     - Handle format-specific fields appropriately")
print("  b) Data Validation:")
print("     - Validate ROC date format (e.g., 1140901)")
print("     - Check numeric ranges (prices > 0, areas > 0)")
print("     - Validate enum values (建物型態, 交易標的)")
print("  c) Missing Value Handling:")
print("     - Define required vs optional fields")
print("     - Set default values where appropriate")
print("     - Document missing value patterns")
print("  d) Data Types:")
print("     - Convert numeric strings to proper numeric types")
print("     - Parse dates to proper date format")
print("     - Normalize text fields (trim, lowercase)")

print("\n[6. NEXT STEPS]")
print("  1. Review field meanings with domain experts")
print("  2. Update ETL scripts based on findings")
print("  3. Implement data validation rules")
print("  4. Create data quality monitoring")
print("  5. Re-import with improved pipeline")
# Out:
# ================================================================================
# ANALYSIS SUMMARY & RECOMMENDATIONS
# ================================================================================
#
# [1. FILE FORMAT UNDERSTANDING]
#   - Transaction (a): General property sales - 32 fields
#   - Pre-sale (b): Pre-construction sales - 30 fields
#   - Rental (c): Property rentals - 34 fields
#
# [2. COMMON FIELDS]
#   - 20 fields shared across all 3 formats
#   - Core fields: 鄉鎮市區, 交易標的, 土地位置建物門牌, 交易年月日, etc.
#
# [3. FORMAT-SPECIFIC FIELDS]
#   Transaction-only: 主建物面積, 移轉編號, 附屬建物面積, 陽台面積, 電梯
#   Pre-sale-only: 建案名稱, 棟及號, 解約情形
#   Rental-only (first 5): 土地面積平方公尺, 建物總面積平方公尺, 租賃住宅服務, 租賃層次, 車位面積平方公尺
#
# [4. DATA QUALITY INSIGHTS]
#   Transaction: 12 fields with missing values
#   Pre-sale:    7 fields with missing values
#   Rental:      16 fields with missing values
#
# [5. RECOMMENDATIONS FOR ETL]
#   a) Field Mapping:
#      - Standardize common field names across 3 formats
#      - Handle format-specific fields appropriately
#   b) Data Validation:
#      - Validate ROC date format (e.g., 1140901)
#      - Check numeric ranges (prices > 0, areas > 0)
#      - Validate enum values (建物型態, 交易標的)
#   c) Missing Value Handling:
#      - Define required vs optional fields
#      - Set default values where appropriate
#      - Document missing value patterns
#   d) Data Types:
#      - Convert numeric strings to proper numeric types
#      - Parse dates to proper date format
#      - Normalize text fields (trim, lowercase)
#
# [6. NEXT STEPS]
#   1. Review field meanings with domain experts
#   2. Update ETL scripts based on findings
#   3. Implement data validation rules
#   4. Create data quality monitoring
#   5. Re-import with improved pipeline
